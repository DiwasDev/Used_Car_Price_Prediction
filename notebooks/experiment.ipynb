# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "/home/divas/ml/logistics_project/data/raw/used_cars.csv"
df = pd.read_csv(file_path)
print(df.head())
# Out:
#       brand                            model  model_year      milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1   Hyundai                     Palisade SEL        2021  34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
data = df.to_dict(orient = "records")
data
# Out:
# [{'brand': 'Ford',
#   'model': 'Utility Police Interceptor Base',
#   'model_year': 2013,
#   'milage': '51,000 mi.',
#   'fuel_type': 'E85 Flex Fuel',
#   'engine': '300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capability',
#   'transmission': '6-Speed A/T',
#   'ext_col': 'Black',
#   'int_col': 'Black',
#   'accident': 'At least 1 accident or damage reported',
#   'clean_title': 'Yes',
#   'price': '$10,300'},
#  {'brand': 'Hyundai',
#   'model': 'Palisade SEL',
#   'model_year': 2021,
#   'milage': '34,742 mi.',
#   'fuel_type': 'Gasoline',
#   'engine': '3.8L V6 24V GDI DOHC',
#   'transmission': '8-Speed Automatic',
#   'ext_col': 'Moonlight Cloud',
#   'int_col': 'Gray',
#   'accident': 'At least 1 accident or damage reported',
#   'clean_title': 'Yes',
#   'price': '$38,005'},
#  {'brand': 'Lexus',
#   'model': 'RX 350 RX 350',
#   'model_year': 2022,
#   'milage': '22,372 mi.',
#   'fuel_type': 'Gasoline',
#   'engine': '3.5 Liter DOHC',
#   'transmission': 'Automatic',
# ...

# %%
DB_NAME = "car_db"
COLLECTION_NAME = "car_db_coll"
uri= "mongodb+srv://diwasdevs_db_user:kcJ55rZuH5nzQ1Ga@cluster0.9b0lqnr.mongodb.net/?appName=Cluster0"

# %%
from pymongo import MongoClient
client = MongoClient(uri)

# %%
database = client[DB_NAME]
collection = database[COLLECTION_NAME]

# %%
record = collection.insert_many(data)

# %%
type(record)
# Out:
# pymongo.results.InsertManyResult

# %%
# PUlling the data
finder = client[DB_NAME][COLLECTION_NAME]

# %%
df = pd.DataFrame(list(finder.find()))

# %%
df
# Out:
#                            _id          brand                         model  \
# 0     6a32c63ef134ab1ed48c79b8        Genesis               GV70 3.5T Sport
# 1     6a32c63ef134ab1ed48c79bc      Chevrolet                  Suburban RST
# 2     6a32c63ef134ab1ed48c79c2  Mercedes-Benz          AMG C 43 Base 4MATIC
# 3     6a32c63ef134ab1ed48c79cc        Bentley          Continental GTC Base
# 4     6a32c63ef134ab1ed48c79ea       Chrysler                     300C SRT8
# ...                        ...            ...                           ...
# 4004  6a32c63ef134ab1ed48c8904         Jaguar                      XK8 Base
# 4005  6a32c63ef134ab1ed48c8909         Subaru          Impreza 2.0i Premium
# 4006  6a32c63ef134ab1ed48c890c     Volkswagen  Beetle 2.0T Final Edition SE
# 4007  6a32c63ef134ab1ed48c8939      Chevrolet             Corvette Stingray
# 4008  6a32c63ef134ab1ed48c893d        Porsche                 911 Carrera S
#
#       model_year      milage      fuel_type  \
# ...
